# %% [markdown]
# # TD n°6

# %% [markdown]
# Importation des différentes librairies

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importation du set de données 'iris.data'

# %%
df = pd.read_csv("http://chendeb.free.fr/iris.data", names=["sl","sw","pl", "pw", "species"])

# %%
df
# Out:
#       sl   sw   pl   pw         species
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Création du scatter plot de 'sl' et 'sw' avec Matplotlib

# %%
sl = df['sl']
sw = df['sw']

plt.scatter(sl, sw)

plt.title('Scatter Plot de sl et sw')
plt.xlabel('Longueur du Sépale (sl)')
plt.ylabel('Largeur du Sépale (sw)')

plt.show()

# %% [markdown]
# Création d'un FacetGrid Plot avec Seaborn

# %%
sl = df['sl']
sw = df['sw']
species = df['species']

g = sns.FacetGrid(df, hue='species', height=5)
g.map(plt.scatter, 'sl', 'sw')

g.set_axis_labels("SepalLengthCm", "SepalWidthCm")
g.add_legend(frameon=True)

plt.show()

# %% [markdown]
# Création d'un Boxplot avec Seaborn

# %%
pl = df['pl']
species = df['species']

sns.boxplot(x=df['species'], y=df['pl']);

plt.ylabel('PetalLengthCm')

plt.show()

# %% [markdown]
# Création d'un Strip plot avec Seaborn

# %%
sl = df['sl']
species = df['species']

sns.stripplot(x="species", y="sl", data=df, hue='species')

plt.legend([],[], frameon=False)
plt.ylabel('SepalLengthCm')

plt.show()

# %% [markdown]
# Création du Pairplot 1 avec Seaborn (A FINIR)

# %%
pl = df['pl']
pw = df['pw']
sl = df['sl']
sw = df['sw']

sns.pairplot(df)

# %% [markdown]
# Création du Pairplot 2 avec Seaborn (A FINIR)

# %% [markdown]
# Création du Pair plot 3 avec Seaborn (A FINIR)

# %%
pl = df['pl']
pw = df['pw']
sl = df['sl']
sw = df['sw']

color_dict = dict(zip(df['species'].unique(), ['blue', 'green', 'red']))

g = sns.pairplot(df, hue='species', kind='reg', palette=color_dict)

plt.show()

# %% [markdown]
# Création de la HeatMap Plot avec Seaborn
